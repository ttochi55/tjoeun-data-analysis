# %% [markdown]
# # plot

# %%
'''
차트 그리기
1. 기본 차트 그리기
2. 산점도 그리기
3. subplot 이용 차트 그리기
'''

import matplotlib.pyplot as plt # 차트 생성
import random # 차트 자료 생성

# 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# 차트 자료 생성
print(random.randint(a=1, b=5)) # 1~5
print(random.random()) # 0~1
print(random.normalvariate(mu=0, sigma=1)) # 표준정규분포
# Out:
# 2
# 0.4239051281837134
# 1.1633802614010251

# %%
# 1. 기본 차트 그리기

# (1) 1개 data
data = range(10) # range(n) 동일 - 0~9

plt.plot(data) # plot(y), x : index
plt.show() # show() 생략 가능

# %%
plt.plot(data, 'r+') # plot(y, 'r+')
plt.show() # show() 생략 가능

# %%
# (2) 2개 data
data2 = [random.random() for i in range(10)]
plt.plot(data, data2) # line
plt.plot(data, data2, 'ro') # point

# %%
# 2. 산점도 그리기
# (1) 단색 산점도
plt.scatter(x=data, y=data2, c='b', marker='o')

# %%
# (2) 여러가지 색 산점도
cdata = [random.randint(a=1, b=3) for i in range(10)]
plt.scatter(x=data, y=data2, c=cdata, marker='o')

# %%
# 3. 히스토그램
data3 = [random.normalvariate(mu=0, sigma=1) for i in range(1000)]
plt.hist(data3)
# Out:
# (array([  7.,  18.,  69., 167., 239., 238., 139.,  79.,  36.,   8.]),
#  array([-3.12682429, -2.50703784, -1.8872514 , -1.26746495, -0.6476785 ,
#         -0.02789206,  0.59189439,  1.21168084,  1.83146728,  2.45125373,
#          3.07104018]),
#  <BarContainer object of 10 artists>)

# %%
# 균등분포
data4 = [random.uniform(a=1, b=100) for i in range(1000)]
plt.hist(data4)
# Out:
# (array([100., 100., 106.,  88.,  92., 108.,  97., 127., 101.,  81.]),
#  array([ 1.11332579, 10.99907314, 20.88482048, 30.77056782, 40.65631516,
#         50.5420625 , 60.42780985, 70.31355719, 80.19930453, 90.08505187,
#         99.97079921]),
#  <BarContainer object of 10 artists>)

# %%
# 차트 크기 지정
fig = plt.figure(figsize=(12, 5)) # (w, h)
chart = fig.add_subplot(1, 1, 1)

data4 = [random.random() for i in range(50)]
data5 = [random.random() for i in range(50)]

plt.hist(data4)
plt.hist(data5)

plt.xlabel('random number') # x축 이름
plt.ylabel('random number') # y축 이름
plt.legend([1, 2]) # 범례
