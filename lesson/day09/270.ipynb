# %%
'''
1. news Crawling
  url : http://media.daum.net
2. pickle save
  binary file save 
'''

import urllib.request as req
from bs4 import BeautifulSoup

url = "http://media.daum.net"

# (1) url 요청 -> html source
res = req.urlopen(url)
source = res.read()
        
# (2) 소스 디코딩
source = source.decode("utf-8") # charset="utf-8"
print(source)
# Out:
# <!DOCTYPE html>
#
#
#
# <html lang="ko" class="os_unknown none unknown version_0 ">
# <head>
# <meta charset="utf-8">
# <meta name="referrer" content="always" />
#
# <meta property="og:author" content="Daum 뉴스" />
# <meta property="og:site_name" content="다음뉴스" />
# <meta property="og:title" content="홈"/>
# <meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />
# <meta property="og:description" content="다음뉴스" />
# <meta property="og:url" content="https://news.daum.net/" />
# <link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">
#
# <title>홈 | 다음뉴스</title>
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/d6ba8ff/style.css.merged.css" />
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/d6ba8ff/calendar.css.merged.css" />
#
# <!--[if lte IE 8]>
# ...

# %%
# (3) html 파싱
html = BeautifulSoup(source, 'html.parser')
print(html)
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/d6ba8ff/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/d6ba8ff/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
# (4) tab[속성=값] 요소 추출
atags = html.select('a[class=link_txt]')

for atag in atags:
    print(atag)    
print("-" * 120)
print('a tag 수 =', len(atags))
# Out:
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20220312173901665" data-tiara-id="20220312173901665" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20220312173901665">
#                                     새정부 5월 출범..내 주식은 언제 오를까[금나와라 뚝딱]
#                                 </a>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20220312173853663" data-tiara-id="20220312173853663" data-tiara-layer="article_main" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://v.daum.net/v/20220312173853663">
#                                     IAEA "우크라, 체르노빌 전력선 복구 작업 시작"[우크라 침공]
#                                 </a>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20220312173613648" data-tiara-id="20220312173613648" data-tiara-layer="article_main" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://v.daum.net/v/20220312173613648">
# ...

# %%
# (5) a 태그 내용 수집
crawling_data = [] # 빈 list

cnt = 0
for atag in atags :
    cnt += 1
    atagStr = str(atag.string) # string 변환 
    #print(cnt, '->', atagStr)
    crawling_data.append(atagStr.strip())
    '''
    string.strip() : 문단 끝 부분 공백, tab, \n\r 불용어 제거 
    '''

# 수집한 자료 확인
print('crawling result')
print(crawling_data)
print(type(crawling_data)) # <class 'list'>
# Out:
# crawling result
# ...

# %%
# text save : object -> file(string) -> load(string) 

file = open('C:/Users/user/python_week/test/day09/data2/crawling_data.txt', mode='w', encoding='utf-8')
file.write(str(crawling_data))  # save
file.close()
print('text file 확인')
# Out:
# text file 확인

# %%
# 5) pickle save/load
'''
picle 
- list, dict 객체를 binary형태로 저장(저용량)
save : pickle.dump(data, file)
laod : pickle.load(file)
'''
import pickle # object -> file(binary) -> load(object)

# save
file = open('C:/Users/user/python_week/test/day09/data2/data.pickle', mode='wb') # binary save
pickle.dump(crawling_data, file)
print('pickle save')
# Out:
# pickle save

# %%
# load
file = open('C:/Users/user/python_week/test/day09/data2/data.pickle', mode='rb') # binary load
crawling_data = pickle.load(file)
print(crawling_data)
# Out:
# ['새정부 5월 출범..내 주식은 언제 오를까[금나와라 뚝딱]', 'IAEA "우크라, 체르노빌 전력선 복구 작업 시작"[우크라 침공]', '울진·삼척 산불 92% 진화..산림청장 "내일 완진 가능할 수도"', '文 \'안희정 부친상 조화\' "피해자 상황에 무감각" 與 의원 \'지적\'', '中서 코로나19 확진자 수 이틀 연속 1000명대.."대부분 무증상자"', "인니 오지 마을에 한국인 온정..'태양광 우물' 선물", '전광훈, 이번에도 대규모 도심 기도회..경찰 "불법 여부 검토 중"', "러, 우크라 수도 키이우로 다시 진격..'도심까지 25km 남아'", '대선 후 첫 주말, 전광훈 지지자 1300명 모였다.."尹지켜내야"', '권지웅·채이배, 민주당 비대위 합류.."당이 필요하다면"', '"9000만원이 2억 됐다는데..솔깃할 수 밖에 없었다" [최예린의 사기꾼 피하기]', '"국제유가 급등세, 기준금리에 영향..부동산 시장 약세 지속될 것"', "청년희망적금 바톤터치..尹표 '청년도약계좌' 관심", '전남도·보성군, 벌교천 범람방지 공사 합동 점검', '러軍, 키이우 36km 떨어진 석유저장소 포격..2곳 화재', '우크라 전쟁에 반도체시장 타격 가시화되나.."핵심원료 공장 중단"', '이대남 "특권 누린 적 없어"..정치권 \'2030 젠더갈등\' 부추겨', '건조특보 속 춘천 홍천 함평 산청 등 전국 곳곳 산불 발생', '충북 오후 4시 6723명 확진..같은 시간대 최다', '"파이팅" 외치고 산불 현장 날아간 공중진화대원[동해안 산불]', '[대만은 지금] 대만 정부와 국민당 "윤석열 당선 축하..한국 관계 심화 기대"', '[영상]"검은 봉지 씌워 끌고 가"..러, 남부도시 시장 구금 뒤 \'테러범\' 주장 [나우,어스]', '"사기꾼 떨고 있나"..\'중고차 진출\' 현대차, 허위매물·바가지 피해도 줄여줄까 [왜몰랐을카]', '\'3:0→3:4\' 고교 축구경기가 조작? 法 "의심되나 증거 부족" [서초동 법썰]', '대한항공 손
# ...
